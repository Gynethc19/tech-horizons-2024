# %% [markdown]
# <a href="https://colab.research.google.com/github/Gynethc19/tech-horizons-2024/blob/main/Clase_11_GC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import kagglehub
from kagglehub import KaggleDatasetAdapter

file_path = "results.csv"

try:
    df = kagglehub.load_dataset(
        KaggleDatasetAdapter.PANDAS,
        "jtrotman/formula-1-race-data",
        file_path,
    )

    print(df.head())
    print(df.tail())
    print(df.shape)
    df.info()
    print(df.describe())

    df['laps_safe'] = df['laps'].replace(0, 1)
    df['points_per_lap'] = df['points'] / df['laps_safe']
    df = df.drop(columns=['laps_safe'])

    print(df[['points', 'laps', 'points_per_lap']].head())

except Exception as e:
    datos = {
        "raceId": [988, 988, 988, 988, 988],
        "driverId": [822, 1, 830, 832, 839],
        "points": [25.0, 18.0, 15.0, 12.0, 10.0],
        "laps": [57, 57, 57, 57, 57],
        "statusId": [1, 1, 1, 1, 1],
        "position": [1, 2, 3, 4, 5]
    }
    df = pd.DataFrame(datos)

    df["laps_safe"] = df["laps"].replace(0, 1)
    df["points_per_lap"] = df["points"] / df["laps_safe"]
    df = df.drop(columns=["laps_safe"])

    print(df.head())
    print(df["points", "laps", "points_per_lap2"].head())
# Out:
# /tmp/ipython-input-3194361374.py:8: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# ...
# 100%|██████████| 1.57M/1.57M [00:00<00:00, 8.81MB/s]
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# ...
